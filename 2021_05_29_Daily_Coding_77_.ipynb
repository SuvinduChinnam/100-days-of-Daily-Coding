# %%
import sys
import pandas as pd
from ast import literal_eval
import ast
import snoop
import fire

# %%
f=open('/Users/suvindu.chinnam/Desktop/TopCell.v.txt')
netlines = f.readlines()
f.close()

# %%
mod_list=[]
cell_name=[]
for i in range(len(netlines)): 
    if netlines[i].lstrip().startswith('module'):
        cell_name.append(netlines[i].split('module ')[1].split('(')[0])        
        temp_list=""
        for j in netlines[i+1:]:
            if j.lstrip().startswith('endmodule'):
                break
            else:
                temp_list=temp_list+j.strip(';\n')
        mod_list.append(temp_list)

# %%
search_list=['cellA ','cellB ','cellC ','cellD ','invN1 ','nand2N1 ','nand4N1 ','nor2N1 ','bufferCell ']

# %%
temp_dict = {}
for i in cell_name:
    temp_dict[i] = None

# %%
for i in range(len(mod_list)):
    temp_ls=[]
    b=f'{cell_name[i]}'
    dict_t={}
    for j in search_list:
        a=mod_list[i].count(j)
        if a!=0:
            dict_t[j]=a
    temp_ls.append(dict_t)  
    temp_dict[b]=temp_ls

# %%
main_df=pd.DataFrame()
for i in temp_dict.keys():
    df=pd.DataFrame(temp_dict[i])
    df['Module']=i
    main_df=pd.concat([main_df,df])

# %%
main_df.columns=main_df.columns.str.strip(" ")
main_df.Module=main_df.Module.str.strip(" ")

# %%
import snoop

# %%
@snoop
def new_d(df,val):
    str_req=[]
    t=get_stuff(df,val,str_req,1) 
    t=('').join(t)
    temp=main_df[main_df['Module']==val]
    temp=temp.dropna(axis=1, how='all')
    l=list(temp.columns)
    l.remove('Module')
    for i in l:
        if i not in primitive:
            print(i, int(temp[i][0]))                  
    for i in primitive:
        gh=t.count(i)
        print(i,gh)

# %%
new_d(main_df,'cellA')
# Out:
# 15:56:44.04 >>> Call to new_d in File "<ipython-input-11-b6eeeca4ca31>", line 2
# 15:56:44.04 ...... df =    cellA  cellC  cellD  invN1  ... nand2N1  nor2N1  bufferCell  cellB
# 15:56:44.04             0    1.0    1.0    1.0    1.0  ...     NaN     NaN         NaN    NaN
# 15:56:44.04             0    NaN    NaN    NaN    2.0  ...     NaN     NaN         NaN    NaN
# 15:56:44.04             0    NaN    NaN    NaN    4.0  ...     NaN     NaN         NaN    NaN
# 15:56:44.04             0    NaN    NaN    NaN    2.0  ...     1.0     2.0         4.0    NaN
# 15:56:44.04             0    4.0    NaN    NaN    2.0  ...     2.0     NaN         NaN    NaN
# 15:56:44.04             0    NaN    1.0    NaN    NaN  ...     NaN     NaN         NaN    2.0
# 15:56:44.04
# 15:56:44.04             [6 rows x 10 columns]
# 15:56:44.04 ...... df.shape = (6, 10)
# 15:56:44.04 ...... val = 'cellA'
# 15:56:44.04    2 | def new_d(df,val):
# 15:56:44.05    3 |     str_req=[]
# 15:56:44.05 .......... str_req = []
# 15:56:44.05    4 |     t=get_stuff(df,val,str_req,1)
#     15:56:44.06 >>> Call to get_stuff in File "<ipython-input-12-7f2c9aaf87c0>", line 2
#     15:56:44.06 ...... df =    cellA  cellC  cellD  invN1  ... nand2N1  nor2N1  bufferCell  cellB
#     15:56:44.06             0    1.0    1.0    1.0    1.0  ...     NaN     NaN         NaN    NaN
#     15:56:44.06             0    NaN    NaN    NaN    2.0  ...     NaN     NaN         NaN    NaN
#     15:56:44.06             0    NaN    NaN    NaN    4.0  ...     NaN     NaN         NaN    NaN
#     15:56:44.06             0    NaN    NaN    NaN    2.0  ...     1.0     2.0         4.0    NaN
#     15:56:44.06             0    4.0    NaN    NaN    2.0  ...     2.0     NaN         NaN    NaN
#     15:56:44.06             0    NaN    1.0    NaN    NaN  ...     NaN     NaN         NaN    2.0
#     15:56:44.06
#     15:56:44.06             [6 rows x 10 columns]
#     15:56:44.06 ...... df.shape = (6, 10)
#     15:56:44.06 ...... val = 'cellA'
#     15:56:44.06 ...... str_req = []
#     15:56:44.06 ...... c = 1
#     15:56:44.06    2 | def get_stuff(df,val,str_req,c):
#     15:56:44.07    3 |     temp=df.copy()
#     15:56:44.08 .......... temp =    cellA  cellC  cellD  invN1  ... nand2N1  nor2N1  bufferCell  cellB
#     15:56:44.08                   0    1.0    1.0    1.0    1.0  ...     NaN     NaN         NaN    NaN
#     15:56:44.08                   0    NaN    NaN    NaN    2.0  ...     NaN     NaN         NaN    NaN
#     15:56:44.08                   0    NaN    NaN    NaN    4.0  ...     NaN     NaN         NaN    NaN
#     15:56:44.08                   0    NaN    NaN    NaN    2.0  ...     1.0     2.0         4.0    NaN
#     15:56:44.08                   0    4.0    NaN    NaN    2.0  ...     2.0     NaN         NaN    NaN
#     15:56:44.08                   0    NaN    1.0    NaN    NaN  ...     NaN     NaN         NaN    2.0
#     15:56:44.08
#     15:56:44.08                   [6 rows x 10 columns]
#     15:56:44.08 .......... temp.shape = (6, 10)
#     15:56:44.08    4 |     temp=temp[temp['Module']==val]
#     15:56:44.09 .......... temp =    cellA  cellC  cellD  invN1  ... nand2N1  nor2N1  bufferCell  cellB
#     15:56:44.09                   0    NaN    NaN    NaN    4.0  ...     NaN     NaN         NaN    NaN
#     15:56:44.09
#     15:56:44.09                   [1 rows x 10 columns]
#     15:56:44.09 .......... temp.shape = (1, 10)
#     15:56:44.09    5 |     temp=temp.dropna(axis=1, how='all')
#     15:56:44.10 .......... temp =    invN1 Module  nand4N1
#     15:56:44.10                   0    4.0  cellA      1.0
#     15:56:44.10 .......... temp.shape = (1, 3)
#     15:56:44.10    6 |     l=list(temp.columns)
#     15:56:44.11 .......... l = ['invN1', 'Module', 'nand4N1']
#     15:56:44.11 .......... len(l) = 3
#     15:56:44.11    7 |     l.remove('Module')
#     15:56:44.12 .......... l = ['invN1', 'nand4N1']
#     15:56:44.12 .......... len(l) = 2
#     15:56:44.12    8 |     for col in l:
#     15:56:44.13 .......... col = 'invN1'
#     15:56:44.13    9 |         if col not in primitive:
#     15:56:44.14   13 |             d=int(temp[col][0])
#     15:56:44.15 .................. d = 4
#     15:56:44.15   14 |             fg=f'{col}_'
#     15:56:44.16 .................. fg = 'invN1_'
#     15:56:44.16   15 |             t=f'{c*d*fg}'
#     15:56:44.16 .................. t = 'invN1_invN1_invN1_invN1_'
#     15:56:44.16   16 |             str_req.append(t)
#     15:56:44.17 .................. str_req = ['invN1_invN1_invN1_invN1_']
#     15:56:44.17 .................. len(str_req) = 1
#     15:56:44.17    8 |     for col in l:
#     15:56:44.18 .......... col = 'nand4N1'
#     15:56:44.18    9 |         if col not in primitive:
#     15:56:44.19   13 |             d=int(temp[col][0])
#     15:56:44.20 .................. d = 1
#     15:56:44.20   14 |             fg=f'{col}_'
#     15:56:44.20 .................. fg = 'nand4N1_'
#     15:56:44.20   15 |             t=f'{c*d*fg}'
#     15:56:44.21 .................. t = 'nand4N1_'
#     15:56:44.21   16 |             str_req.append(t)
#     15:56:44.22 .................. str_req = ['invN1_invN1_invN1_invN1_', 'nand4N1_']
#     15:56:44.22 .................. len(str_req) = 2
#     15:56:44.22    8 |     for col in l:
#     15:56:44.22   17 |     output=str_req
#     15:56:44.23 .......... output = ['invN1_invN1_invN1_invN1_', 'nand4N1_']
#     15:56:44.23 .......... len(output) = 2
#     15:56:44.23   18 |     return output
#     15:56:44.24 <<< Return value from get_stuff: ['invN1_invN1_invN1_invN1_', 'nand4N1_']
# 15:56:44.24    4 |     t=get_stuff(df,val,str_req,1)
# 15:56:44.24 .......... str_req = ['invN1_invN1_invN1_invN1_', 'nand4N1_']
# 15:56:44.24 .......... len(str_req) = 2
# 15:56:44.24 .......... t = ['invN1_invN1_invN1_invN1_', 'nand4N1_']
# 15:56:44.24 .......... len(t) = 2
# 15:56:44.24    5 |     t=('').join(t)
# 15:56:44.25 .......... t = 'invN1_invN1_invN1_invN1_nand4N1_'
# 15:56:44.25    6 |     temp=main_df[main_df['Module']==val]
# 15:56:44.25 .......... temp =    cellA  cellC  cellD  invN1  ... nand2N1  nor2N1  bufferCell  cellB
# 15:56:44.25                   0    NaN    NaN    NaN    4.0  ...     NaN     NaN         NaN    NaN
# 15:56:44.25
# 15:56:44.25                   [1 rows x 10 columns]
# 15:56:44.25 .......... temp.shape = (1, 10)
# 15:56:44.25    7 |     temp=temp.dropna(axis=1, how='all')
# 15:56:44.26 .......... temp =    invN1 Module  nand4N1
# 15:56:44.26                   0    4.0  cellA      1.0
# 15:56:44.26 .......... temp.shape = (1, 3)
# 15:56:44.26    8 |     l=list(temp.columns)
# 15:56:44.27 .......... l = ['invN1', 'Module', 'nand4N1']
# 15:56:44.27 .......... len(l) = 3
# 15:56:44.27    9 |     l.remove('Module')
# 15:56:44.28 .......... l = ['invN1', 'nand4N1']
# 15:56:44.28 .......... len(l) = 2
# 15:56:44.28   10 |     for i in l:
# 15:56:44.28 .......... i = 'invN1'
# 15:56:44.28   11 |         if i not in primitive:
# 15:56:44.29   10 |     for i in l:
# 15:56:44.30 .......... i = 'nand4N1'
# 15:56:44.30   11 |         if i not in primitive:
# 15:56:44.30   10 |     for i in l:
# 15:56:44.31   13 |     for i in primitive:
# 15:56:44.31 .......... i = 'invN1'
# 15:56:44.31   14 |         gh=t.count(i)
# 15:56:44.32 .............. gh = 4
# 15:56:44.32   15 |         print(i,gh)
# 15:56:44.32   13 |     for i in primitive:
# 15:56:44.33 .......... i = 'nand4N1'
# 15:56:44.33   14 |         gh=t.count(i)
# 15:56:44.33 .............. gh = 1
# 15:56:44.33   15 |         print(i,gh)
# 15:56:44.34   13 |     for i in primitive:
# 15:56:44.34 .......... i = 'nand2N1'
# 15:56:44.34   14 |         gh=t.count(i)
# 15:56:44.35 .............. gh = 0
# 15:56:44.35   15 |         print(i,gh)
# 15:56:44.35   13 |     for i in primitive:
# 15:56:44.36 .......... i = 'nor2N1'
# 15:56:44.36   14 |         gh=t.count(i)
# 15:56:44.36   15 |         print(i,gh)
# 15:56:44.37   13 |     for i in primitive:
# 15:56:44.37 <<< Return value from new_d: None
# invN1 4
# nand4N1 1
# nand2N1 0
# nor2N1 0

# %%
new_d(main_df,'cellA')
# Out:
# 15:56:21.51 >>> Call to new_d in File "<ipython-input-11-b6eeeca4ca31>", line 2
# 15:56:21.51 ...... df =    cellA  cellC  cellD  invN1  ... nand2N1  nor2N1  bufferCell  cellB
# 15:56:21.51             0    1.0    1.0    1.0    1.0  ...     NaN     NaN         NaN    NaN
# 15:56:21.51             0    NaN    NaN    NaN    2.0  ...     NaN     NaN         NaN    NaN
# 15:56:21.51             0    NaN    NaN    NaN    4.0  ...     NaN     NaN         NaN    NaN
# 15:56:21.51             0    NaN    NaN    NaN    2.0  ...     1.0     2.0         4.0    NaN
# 15:56:21.51             0    4.0    NaN    NaN    2.0  ...     2.0     NaN         NaN    NaN
# 15:56:21.51             0    NaN    1.0    NaN    NaN  ...     NaN     NaN         NaN    2.0
# 15:56:21.51
# 15:56:21.51             [6 rows x 10 columns]
# 15:56:21.51 ...... df.shape = (6, 10)
# 15:56:21.51 ...... val = 'cellA'
# 15:56:21.51    2 | def new_d(df,val):
# 15:56:21.52    3 |     str_req=[]
# 15:56:21.53 .......... str_req = []
# 15:56:21.53    4 |     t=get_stuff(df,val,str_req,1)
#     15:56:21.53 >>> Call to get_stuff in File "<ipython-input-12-7f2c9aaf87c0>", line 2
#     15:56:21.53 ...... df =    cellA  cellC  cellD  invN1  ... nand2N1  nor2N1  bufferCell  cellB
#     15:56:21.53             0    1.0    1.0    1.0    1.0  ...     NaN     NaN         NaN    NaN
#     15:56:21.53             0    NaN    NaN    NaN    2.0  ...     NaN     NaN         NaN    NaN
#     15:56:21.53             0    NaN    NaN    NaN    4.0  ...     NaN     NaN         NaN    NaN
#     15:56:21.53             0    NaN    NaN    NaN    2.0  ...     1.0     2.0         4.0    NaN
#     15:56:21.53             0    4.0    NaN    NaN    2.0  ...     2.0     NaN         NaN    NaN
#     15:56:21.53             0    NaN    1.0    NaN    NaN  ...     NaN     NaN         NaN    2.0
#     15:56:21.53
#     15:56:21.53             [6 rows x 10 columns]
#     15:56:21.53 ...... df.shape = (6, 10)
#     15:56:21.53 ...... val = 'cellA'
#     15:56:21.53 ...... str_req = []
#     15:56:21.53 ...... c = 1
#     15:56:21.53    2 | def get_stuff(df,val,str_req,c):
#     15:56:21.54    3 |     temp=df.copy()
#     15:56:21.55 .......... temp =    cellA  cellC  cellD  invN1  ... nand2N1  nor2N1  bufferCell  cellB
#     15:56:21.55                   0    1.0    1.0    1.0    1.0  ...     NaN     NaN         NaN    NaN
#     15:56:21.55                   0    NaN    NaN    NaN    2.0  ...     NaN     NaN         NaN    NaN
#     15:56:21.55                   0    NaN    NaN    NaN    4.0  ...     NaN     NaN         NaN    NaN
#     15:56:21.55                   0    NaN    NaN    NaN    2.0  ...     1.0     2.0         4.0    NaN
#     15:56:21.55                   0    4.0    NaN    NaN    2.0  ...     2.0     NaN         NaN    NaN
#     15:56:21.55                   0    NaN    1.0    NaN    NaN  ...     NaN     NaN         NaN    2.0
#     15:56:21.55
#     15:56:21.55                   [6 rows x 10 columns]
#     15:56:21.55 .......... temp.shape = (6, 10)
#     15:56:21.55    4 |     temp=temp[temp['Module']==val]
#     15:56:21.56 .......... temp =    cellA  cellC  cellD  invN1  ... nand2N1  nor2N1  bufferCell  cellB
#     15:56:21.56                   0    NaN    NaN    NaN    4.0  ...     NaN     NaN         NaN    NaN
#     15:56:21.56
#     15:56:21.56                   [1 rows x 10 columns]
#     15:56:21.56 .......... temp.shape = (1, 10)
#     15:56:21.56    5 |     temp=temp.dropna(axis=1, how='all')
#     15:56:21.57 .......... temp =    invN1 Module  nand4N1
#     15:56:21.57                   0    4.0  cellA      1.0
#     15:56:21.57 .......... temp.shape = (1, 3)
#     15:56:21.57    6 |     l=list(temp.columns)
#     15:56:21.57 .......... l = ['invN1', 'Module', 'nand4N1']
#     15:56:21.57 .......... len(l) = 3
#     15:56:21.57    7 |     l.remove('Module')
#     15:56:21.58 .......... l = ['invN1', 'nand4N1']
#     15:56:21.58 .......... len(l) = 2
#     15:56:21.58    8 |     for col in l:
#     15:56:21.59 .......... col = 'invN1'
#     15:56:21.59    9 |         if col not in primitive:
#     15:56:21.59   13 |             d=int(temp[col][0])
#     15:56:21.60 .................. d = 4
#     15:56:21.60   14 |             fg=f'{col}_'
#     15:56:21.61 .................. fg = 'invN1_'
#     15:56:21.61   15 |             t=f'{c*d*fg}'
#     15:56:21.61 .................. t = 'invN1_invN1_invN1_invN1_'
#     15:56:21.61   16 |             str_req.append(t)
#     15:56:21.62 .................. str_req = ['invN1_invN1_invN1_invN1_']
#     15:56:21.62 .................. len(str_req) = 1
#     15:56:21.62    8 |     for col in l:
#     15:56:21.62 .......... col = 'nand4N1'
#     15:56:21.62    9 |         if col not in primitive:
#     15:56:21.63   13 |             d=int(temp[col][0])
#     15:56:21.64 .................. d = 1
#     15:56:21.64   14 |             fg=f'{col}_'
#     15:56:21.64 .................. fg = 'nand4N1_'
#     15:56:21.64   15 |             t=f'{c*d*fg}'
#     15:56:21.65 .................. t = 'nand4N1_'
#     15:56:21.65   16 |             str_req.append(t)
#     15:56:21.65 .................. str_req = ['invN1_invN1_invN1_invN1_', 'nand4N1_']
#     15:56:21.65 .................. len(str_req) = 2
#     15:56:21.65    8 |     for col in l:
#     15:56:21.66   17 |     output=str_req
#     15:56:21.67 .......... output = ['invN1_invN1_invN1_invN1_', 'nand4N1_']
#     15:56:21.67 .......... len(output) = 2
#     15:56:21.67   18 |     return output
#     15:56:21.67 <<< Return value from get_stuff: ['invN1_invN1_invN1_invN1_', 'nand4N1_']
# 15:56:21.67    4 |     t=get_stuff(df,val,str_req,1)
# 15:56:21.68 .......... str_req = ['invN1_invN1_invN1_invN1_', 'nand4N1_']
# 15:56:21.68 .......... len(str_req) = 2
# 15:56:21.68 .......... t = ['invN1_invN1_invN1_invN1_', 'nand4N1_']
# 15:56:21.68 .......... len(t) = 2
# 15:56:21.68    5 |     t=('').join(t)
# 15:56:21.68 .......... t = 'invN1_invN1_invN1_invN1_nand4N1_'
# 15:56:21.68    6 |     temp=main_df[main_df['Module']==val]
# 15:56:21.69 .......... temp =    cellA  cellC  cellD  invN1  ... nand2N1  nor2N1  bufferCell  cellB
# 15:56:21.69                   0    NaN    NaN    NaN    4.0  ...     NaN     NaN         NaN    NaN
# 15:56:21.69
# 15:56:21.69                   [1 rows x 10 columns]
# 15:56:21.69 .......... temp.shape = (1, 10)
# 15:56:21.69    7 |     temp=temp.dropna(axis=1, how='all')
# 15:56:21.70 .......... temp =    invN1 Module  nand4N1
# 15:56:21.70                   0    4.0  cellA      1.0
# 15:56:21.70 .......... temp.shape = (1, 3)
# 15:56:21.70    8 |     l=list(temp.columns)
# 15:56:21.70 .......... l = ['invN1', 'Module', 'nand4N1']
# 15:56:21.70 .......... len(l) = 3
# 15:56:21.70    9 |     l.remove('Module')
# 15:56:21.71 .......... l = ['invN1', 'nand4N1']
# 15:56:21.71 .......... len(l) = 2
# 15:56:21.71   10 |     for i in l:
# 15:56:21.72 .......... i = 'invN1'
# 15:56:21.72   11 |         if i not in primitive:
# 15:56:21.72   10 |     for i in l:
# 15:56:21.73 .......... i = 'nand4N1'
# 15:56:21.73   11 |         if i not in primitive:
# 15:56:21.73   10 |     for i in l:
# 15:56:21.74   13 |     for i in primitive:
# 15:56:21.74 .......... i = 'invN1'
# 15:56:21.74   14 |         gh=t.count(i)
# 15:56:21.75 .............. gh = 4
# 15:56:21.75   15 |         print(i,gh)
# 15:56:21.75   13 |     for i in primitive:
# 15:56:21.76 .......... i = 'nand4N1'
# 15:56:21.76   14 |         gh=t.count(i)
# 15:56:21.76 .............. gh = 1
# 15:56:21.76   15 |         print(i,gh)
# 15:56:21.77   13 |     for i in primitive:
# 15:56:21.77 .......... i = 'nand2N1'
# 15:56:21.77   14 |         gh=t.count(i)
# 15:56:21.78 .............. gh = 0
# 15:56:21.78   15 |         print(i,gh)
# 15:56:21.78   13 |     for i in primitive:
# 15:56:21.79 .......... i = 'nor2N1'
# 15:56:21.79   14 |         gh=t.count(i)
# 15:56:21.79   15 |         print(i,gh)
# 15:56:21.80   13 |     for i in primitive:
# 15:56:21.80 <<< Return value from new_d: None
# invN1 4
# nand4N1 1
# nand2N1 0
# nor2N1 0
